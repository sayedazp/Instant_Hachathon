# %%
import numpy as np
import pandas as pd

# %%
temp_dat = pd.read_csv("Temperature_change_Data.csv")

# %%
temp_dat.head()
# Out:
#   Country Code    Country Name  year  tem_change
# 0          AFG     Afghanistan  1961      -0.080
# 1          ALB         Albania  1961       0.631
# 2          DZA         Algeria  1961       0.186
# 3          ASM  American Samoa  1961      -0.014
# 4          AND         Andorra  1961       0.749

# %%
temp_dat.year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019], dtype=int64)

# %%
temp_dat['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize', 'Benin',
#        'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
temp_dat.describe()
# Out:
#                year    tem_change
# count  16756.000000  14975.000000
# mean    1990.000000      0.484160
# std       17.029895      0.628342
# min     1961.000000     -3.252000
# 25%     1975.000000      0.035000
# 50%     1990.000000      0.412000
# 75%     2005.000000      0.882000
# max     2019.000000      5.413000

# %%
temp_dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16756 entries, 0 to 16755
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  14042 non-null  object
#  1   Country Name  16756 non-null  object
#  2   year          16756 non-null  int64
#  3   tem_change    14975 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 523.8+ KB

# %%
#there are null country codes and null tem_change
#how to handle them !

# %%
temp_dat[temp_dat['Country Code'].isnull()]
# Out:
#       Country Code                             Country Name  year  tem_change
# 21             NaN                       Belgium-Luxembourg  1961       0.872
# 46             NaN                          China, mainland  1961       0.264
# 60             NaN                           Czechoslovakia  1961       1.160
# 75             NaN                             Ethiopia PDR  1961      -0.061
# 81             NaN                            French Guiana  1961      -0.121
# ...            ...                                      ...   ...         ...
# 16751          NaN        Low Income Food Deficit Countries  2019       1.244
# 16752          NaN  Net Food Importing Developing Countries  2019       1.412
# 16753          NaN                        Annex I countries  2019       1.627
# 16754          NaN                    Non-Annex I countries  2019       1.361
# 16755          NaN                                     OECD  2019       1.297
#
# [2714 rows x 4 columns]

# %%
temp_dat[temp_dat['Country Name'] == 'Belgium-Luxembourg']
# Out:
#       Country Code        Country Name  year  tem_change
# 21             NaN  Belgium-Luxembourg  1961       0.872
# 305            NaN  Belgium-Luxembourg  1962      -0.803
# 589            NaN  Belgium-Luxembourg  1963      -1.171
# 873            NaN  Belgium-Luxembourg  1964      -0.214
# 1157           NaN  Belgium-Luxembourg  1965      -0.763
# 1441           NaN  Belgium-Luxembourg  1966       0.478
# 1725           NaN  Belgium-Luxembourg  1967       0.678
# 2009           NaN  Belgium-Luxembourg  1968      -0.021
# 2293           NaN  Belgium-Luxembourg  1969      -0.013
# 2577           NaN  Belgium-Luxembourg  1970      -0.472
# 2861           NaN  Belgium-Luxembourg  1971      -0.020
# 3145           NaN  Belgium-Luxembourg  1972      -0.177
# 3429           NaN  Belgium-Luxembourg  1973       0.182
# 3713           NaN  Belgium-Luxembourg  1974       0.167
# 3997           NaN  Belgium-Luxembourg  1975       0.945
# ...

# %%
#export null country names
nan_list = temp_dat[temp_dat['Country Code'].isnull()]['Country Name'].to_list()

# %%
#unit testing if there is a country with a null code not in null list
temp_dat[~temp_dat['Country Name'].isin(nan_list) & temp_dat['Country Code'].isnull() ]
#which is not true
# Out:
# Empty DataFrame
# Columns: [Country Code, Country Name, year, tem_change]
# Index: []

# %%
temp_dat[temp_dat['tem_change'].isnull()][['year']].describe()
# Out:
#               year
# count  1781.000000
# mean   1985.281864
# std      16.047341
# min    1961.000000
# 25%    1972.000000
# 50%    1983.000000
# 75%    1997.000000
# max    2019.000000

# %%
temp_dat['tem_change'].describe()
# Out:
# count    14975.000000
# mean         0.484160
# std          0.628342
# min         -3.252000
# 25%          0.035000
# 50%          0.412000
# 75%          0.882000
# max          5.413000
# Name: tem_change, dtype: float64

# %%
temp_dat['tem_change'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# !pip install missingno
# Out:
# ...
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: C:\Users\Sayed\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
# Visualize missingness
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']])
plt.show()

# %%
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']].sort_values(by = 'year'))
plt.show()

# %%
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']].sort_values(by = 'Country Name'))
plt.show()

# %%
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']].sort_values(by = ['Country Name' , 'year']))
plt.show()

# %%
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']].sort_values(by = ['year' , 'Country Name']))
plt.show()

# %%
group1 = temp_dat.groupby(['Country Name' , 'year'] )

# %%
group1.head()
# Out:
#       Country Code                             Country Name  year  tem_change
# 0              AFG                              Afghanistan  1961      -0.080
# 1              ALB                                  Albania  1961       0.631
# 2              DZA                                  Algeria  1961       0.186
# 3              ASM                           American Samoa  1961      -0.014
# 4              AND                                  Andorra  1961       0.749
# ...            ...                                      ...   ...         ...
# 16751          NaN        Low Income Food Deficit Countries  2019       1.244
# 16752          NaN  Net Food Importing Developing Countries  2019       1.412
# 16753          NaN                        Annex I countries  2019       1.627
# 16754          NaN                    Non-Annex I countries  2019       1.361
# 16755          NaN                                     OECD  2019       1.297
#
# [16756 rows x 4 columns]

# %%
msno.matrix(temp_dat[['Country Name' , "year" , 'tem_change']].sort_values(by = ['Country Name' , 'year']))
plt.show()

# %%
table1 = pd.pivot_table(temp_dat , index = ['Country Name' , 'year'] , dropna = False )

# %%
msno.matrix(table1)
plt.show()

# %%
table1
# Out:
#                    tem_change
# Country Name year
# Afghanistan  1961      -0.080
#              1962      -0.120
#              1963       0.882
#              1964      -0.727
#              1965      -0.200
# ...                       ...
# Zimbabwe     2015       1.091
#              2016       1.303
#              2017       0.269
#              2018       0.496
#              2019       1.157
#
# [16756 rows x 1 columns]

# %%
null = table1[table1.tem_change.isnull()]

# %%
null
# Out:
#                      tem_change
# Country Name   year
# American Samoa 1993         NaN
#                1994         NaN
#                1997         NaN
#                1998         NaN
#                2009         NaN
# ...                         ...
# Yugoslav SFR   2015         NaN
#                2016         NaN
#                2017         NaN
#                2018         NaN
#                2019         NaN
#
# [1781 rows x 1 columns]

# %%
table1[~table1.tem_change.isnull()]
# Out:
#                    tem_change
# Country Name year
# Afghanistan  1961      -0.080
#              1962      -0.120
#              1963       0.882
#              1964      -0.727
#              1965      -0.200
# ...                       ...
# Zimbabwe     2015       1.091
#              2016       1.303
#              2017       0.269
#              2018       0.496
#              2019       1.157
#
# [14975 rows x 1 columns]

# %%
table1.iloc[(0)]
# Out:
# tem_change   -0.08
# Name: (Afghanistan, 1961), dtype: float64

# %%
#having no domain knowledge , knowng there is no more valuable columns to save , choose to drop nulls

# %%
df = temp_dat.dropna(subset = ['tem_change'] , axis = 0)

# %%
df.head()
# Out:
#   Country Code    Country Name  year  tem_change
# 0          AFG     Afghanistan  1961      -0.080
# 1          ALB         Albania  1961       0.631
# 2          DZA         Algeria  1961       0.186
# 3          ASM  American Samoa  1961      -0.014
# 4          AND         Andorra  1961       0.749

# %%
df.tem_change.isna().any()
# Out:
# False

# %%
#df['year'] = pd.to_datetime(df['year'])

# %%
df.head()
# Out:
#   Country Code    Country Name  year  tem_change
# 0          AFG     Afghanistan  1961      -0.080
# 1          ALB         Albania  1961       0.631
# 2          DZA         Algeria  1961       0.186
# 3          ASM  American Samoa  1961      -0.014
# 4          AND         Andorra  1961       0.749

# %%
df.sort_values('year' , ascending = True)
# Out:
#       Country Code                                  Country Name  year  \
# 0              AFG                                   Afghanistan  1961
# 183            RWA                                        Rwanda  1961
# 184            SHN  Saint Helena, Ascension and Tristan da Cunha  1961
# 185            KNA                         Saint Kitts and Nevis  1961
# 186            LCA                                   Saint Lucia  1961
# ...            ...                                           ...   ...
# 16570          HTI                                         Haiti  2019
# 16571          VAT                                      Holy See  2019
# 16572          HND                                      Honduras  2019
# 16558          GEO                                       Georgia  2019
# 16755          NaN                                          OECD  2019
#
#        tem_change
# 0          -0.080
# 183         0.002
# 184         0.159
# 185         0.057
# ...

# %%
#df['year'] = df['year'].dt.date

# %%
df.year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019], dtype=int64)

# %%
sum_climate = df.groupby('Country Name').sum().sort_values('tem_change' , ascending = False)
print(sum_climate.head())
# Out:
#                                   year  tem_change
# Country Name
# Mongolia                        117410      50.370
# Svalbard and Jan Mayen Islands  117410      50.025
# Gambia                          117410      48.453
# Morocco                         117410      47.314
# Guinea-Bissau                   117410      47.290

# %%
top10 = sum_climate.head(10)
print(top10['tem_change'])
# Out:
# Country Name
# Mongolia                          50.370
# Svalbard and Jan Mayen Islands    50.025
# Gambia                            48.453
# Morocco                           47.314
# Guinea-Bissau                     47.290
# Tunisia                           46.848
# Mauritania                        44.865
# Eastern Europe                    44.689
# Austria                           44.165
# Senegal                           43.608
# Name: tem_change, dtype: float64

# %%
least10 = sum_climate.tail(10)
print(least10['tem_change'])
# Out:
# Country Name
# Niue                               4.465
# Yemen                              4.460
# Singapore                          4.228
# Marshall Islands                   2.866
# Yugoslav SFR                       1.097
# Pacific Islands Trust Territory    0.992
# Midway Island                      0.323
# Falkland Islands (Malvinas)        0.168
# Pitcairn Islands                  -1.175
# Nauru                             -1.757
# Name: tem_change, dtype: float64

# %%
temp_dat[temp_dat['tem_change'].isnull()]
# Out:
#       Country Code            Country Name  year  tem_change
# 10             ARM                 Armenia  1961         NaN
# 14             AZE              Azerbaijan  1961         NaN
# 19             BLR                 Belarus  1961         NaN
# 20             BEL                 Belgium  1961         NaN
# 26             BIH  Bosnia and Herzegovina  1961         NaN
# ...            ...                     ...   ...         ...
# 16691          TKL                 Tokelau  2019         NaN
# 16707          NaN                    USSR  2019         NaN
# 16712          WAK             Wake Island  2019         NaN
# 16715          YEM                   Yemen  2019         NaN
# 16716          NaN            Yugoslav SFR  2019         NaN
#
# [1781 rows x 4 columns]

# %%
#export null country names
nan_list2 = temp_dat[temp_dat['tem_change'].isnull()]['Country Name'].to_list()

# %%
nan_c_non = temp_dat[temp_dat['Country Name'].isin(nan_list2) & ~temp_dat['tem_change'].isnull()]

# %%
nan_c_non.sort_values(['Country Name' , 'year'])
# Out:
#      Country Code    Country Name  year  tem_change
# 3             ASM  American Samoa  1961      -0.014
# 287           ASM  American Samoa  1962      -0.080
# 571           ASM  American Samoa  1963       0.072
# 855           ASM  American Samoa  1964      -0.226
# 1139          ASM  American Samoa  1965      -0.473
# ...           ...             ...   ...         ...
# 7628          NaN    Yugoslav SFR  1987      -0.172
# 7912          NaN    Yugoslav SFR  1988       0.488
# 8196          NaN    Yugoslav SFR  1989       0.408
# 8480          NaN    Yugoslav SFR  1990       0.999
# 8764          NaN    Yugoslav SFR  1991      -0.115
#
# [3116 rows x 4 columns]

# %%
plt.hist(nan_c_non['tem_change'])
# Out:
# (array([  8.,  82., 484., 866., 683., 445., 328., 131.,  68.,  21.]),
#  array([-1.278 , -0.8649, -0.4518, -0.0387,  0.3744,  0.7875,  1.2006,
#          1.6137,  2.0268,  2.4399,  2.853 ]),
#  <a list of 10 Patch objects>)

# %%
table2 = pd.pivot_table(nan_c_non , index = ['Country Name' , 'year'] )

# %%
sns.set(rc = {'figure.figsize' :(15 , 15)})
ax = sns.histplot(data = nan_c_non , x = 'tem_change' , hue = ('year') , multiple = 'layer'  ,kde = True )
ax.set_title("climate change distribution over years")
# Out:
# Text(0.5, 1.0, 'climate change distribution over years')

# %%
sns.set(rc = {'figure.figsize' :(15 , 15)})
ax = sns.histplot(data = nan_c_non , x = 'tem_change' , hue = ('Country Name') , multiple = 'layer'  ,kde = True, alpha = .7 , palette = sns.color_palette("mako"))
ax.set_title("climate change distribution over countries")
# Out:
# <ipython-input-43-508ee8ef0714>:2: UserWarning:
# The palette list has fewer values (6) than needed (83) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.histplot(data = nan_c_non , x = 'tem_change' , hue = ('Country Name') , multiple = 'layer'  ,kde = True, alpha = .7 , palette = sns.color_palette("mako"))
# Text(0.5, 1.0, 'climate change distribution over countries')

# %%
df[['year' , 'tem_change']]
# Out:
#        year  tem_change
# 0      1961      -0.080
# 1      1961       0.631
# 2      1961       0.186
# 3      1961      -0.014
# 4      1961       0.749
# ...     ...         ...
# 16751  2019       1.244
# 16752  2019       1.412
# 16753  2019       1.627
# 16754  2019       1.361
# 16755  2019       1.297
#
# [14975 rows x 2 columns]

# %%
df
# Out:
#       Country Code                             Country Name  year  tem_change
# 0              AFG                              Afghanistan  1961      -0.080
# 1              ALB                                  Albania  1961       0.631
# 2              DZA                                  Algeria  1961       0.186
# 3              ASM                           American Samoa  1961      -0.014
# 4              AND                                  Andorra  1961       0.749
# ...            ...                                      ...   ...         ...
# 16751          NaN        Low Income Food Deficit Countries  2019       1.244
# 16752          NaN  Net Food Importing Developing Countries  2019       1.412
# 16753          NaN                        Annex I countries  2019       1.627
# 16754          NaN                    Non-Annex I countries  2019       1.361
# 16755          NaN                                     OECD  2019       1.297
#
# [14975 rows x 4 columns]

# %%
df.groupby(df.year).mean().sort_values(by ='tem_change' , ascending = False)
# Out:
#       tem_change
# year
# 2016    1.468284
# 2019    1.443481
# 2018    1.307709
# 2017    1.301789
# 2015    1.285736
# 2014    1.123158
# 2010    1.122019
# 2007    1.028390
# 1998    0.969641
# 2013    0.956744
# 2009    0.935700
# 2002    0.920863
# 2012    0.916589
# 2006    0.894813
# 2005    0.878186
# 2003    0.847217
# 2011    0.835892
# 2001    0.834709
# 2008    0.809573
# 2004    0.785777
# 1999    0.749031
# 2000    0.668065
# 1995    0.636172
# 1994    0.581753
# 1990    0.573261
# 1997    0.539236
# 1988    0.475261
# 1991    0.373477
# 1987    0.365744
# 1983    0.345508
# 1996    0.303722
# 1989    0.263939
# 1980    0.245718
# 1973    0.238936
# 1992    0.232180
# 1993    0.219629
# 1979    0.219171
# 1981    0.194947
# 1961    0.170922
# 1977    0.166094
# 1982    0.164478
# 1986    0.152861
# 1969    0.117191
# 1966    0.098972
# 1984    0.092090
# 1970    0.078967
# 1978    0.059012
# 1985    0.058295
# 1975   -0.002631
# 1962   -0.022873
# 1963   -0.028361
# ...

# %%
year_chng_mean = df.groupby('year').mean()

# %%
ax = sns.lineplot(data =  year_chng_mean)
ax.set_title("the average change in climate over years")
# Out:
# Text(0.5, 1.0, 'the average change in climate over years')

# %%
ax = sns.violinplot(data = df , x = 'Country Name' , y = 'tem_change')
ax.tick_params(axis='x', rotation=90)

# %%
sns.violinplot(data = df , x = 'year' , y = 'tem_change')

# %%
import random

# %%
names = df['Country Name'].unique()

r_names = random.choices(names, k=5)

# %%
df_filtered = df[df['Country Name'].isin(r_names)]

# %%
ax = sns.violinplot(data = df_filtered , x = 'Country Name' , y = 'tem_change')
ax.tick_params(axis='x', rotation=90)

# %%
#can fixing the country and averaging over years solve ?
#names2
#r_names2

# %%
names2 = df['year'].unique()

r_names2 = random.choices(names2, k=5)
df_filtered2 = df[df['year'].isin(r_names2)]

# %%
sns.violinplot(data = df_filtered2 , x = 'year' , y = 'tem_change')
# Out:
# <AxesSubplot:xlabel='year', ylabel='tem_change'>

# %%
np.mean(df.tem_change)
# Out:
# 0.4841599999999978

# %%
yr_grouped = df.groupby('year').mean()
print(yr_grouped)
# Out:
#       tem_change
# year
# 1961    0.170922
# 1962   -0.022873
# 1963   -0.028361
# 1964   -0.106037
# 1965   -0.254930
# 1966    0.098972
# 1967   -0.107878
# 1968   -0.199280
# 1969    0.117191
# 1970    0.078967
# 1971   -0.184592
# 1972   -0.068146
# 1973    0.238936
# 1974   -0.154871
# 1975   -0.002631
# 1976   -0.241992
# 1977    0.166094
# 1978    0.059012
# 1979    0.219171
# 1980    0.245718
# 1981    0.194947
# 1982    0.164478
# 1983    0.345508
# 1984    0.092090
# 1985    0.058295
# 1986    0.152861
# 1987    0.365744
# 1988    0.475261
# 1989    0.263939
# 1990    0.573261
# 1991    0.373477
# 1992    0.232180
# 1993    0.219629
# 1994    0.581753
# 1995    0.636172
# 1996    0.303722
# 1997    0.539236
# 1998    0.969641
# 1999    0.749031
# 2000    0.668065
# 2001    0.834709
# 2002    0.920863
# 2003    0.847217
# 2004    0.785777
# 2005    0.878186
# 2006    0.894813
# 2007    1.028390
# 2008    0.809573
# 2009    0.935700
# 2010    1.122019
# 2011    0.835892
# ...

# %%
yr_grouped_sorted = yr_grouped.sort_values(by = 'tem_change' , ascending = False)
print(yr_grouped_sorted.head(10))
# Out:
#       tem_change
# year
# 2016    1.468284
# 2019    1.443481
# 2018    1.307709
# 2017    1.301789
# 2015    1.285736
# 2014    1.123158
# 2010    1.122019
# 2007    1.028390
# 1998    0.969641
# 2013    0.956744

# %%
cnam_grouped = df.groupby('Country Name')[['tem_change']].mean()
print(cnam_grouped)
# Out:
#                 tem_change
# Country Name
# Afghanistan       0.432322
# Africa            0.491475
# Albania           0.485492
# Algeria           0.711153
# American Samoa    0.465000
# ...                    ...
# World             0.523542
# Yemen             0.143871
# Yugoslav SFR      0.035387
# Zambia            0.451712
# Zimbabwe          0.284644
#
# [284 rows x 1 columns]

# %%
cnam_grouped_sorted = cnam_grouped.sort_values(by = 'tem_change' , ascending = False)
print(cnam_grouped_sorted.tail(10))
# Out:
#                                               tem_change
# Country Name
# Czechoslovakia                                  0.144000
# Yemen                                           0.143871
# South Georgia and the South Sandwich Islands    0.138115
# Marshall Islands                                0.098828
# Yugoslav SFR                                    0.035387
# Pacific Islands Trust Territory                 0.033067
# Midway Island                                   0.020187
# Falkland Islands (Malvinas)                     0.008000
# Pitcairn Islands                               -0.023980
# Nauru                                          -0.103353

# %%
cnam_grouped_sorted = cnam_grouped.sort_values(by = 'tem_change' , ascending = False)
print(cnam_grouped_sorted.head(10))
# Out:
#                     tem_change
# Country Name
# Serbia                1.511571
# Luxembourg            1.487400
# Montenegro            1.483143
# Estonia               1.455321
# Belgium               1.422800
# Slovenia              1.420500
# Russian Federation    1.401893
# Latvia                1.401071
# Belarus               1.399250
# Lithuania             1.355893

# %%
#cnam_grouped_sorted.reset_index(inplace= True)
#cnam_grouped_sorted

# %%
ax = sns.histplot(yr_grouped )
ax.set_title("average temp change by year")
# Out:
# Text(0.5, 1.0, 'average temp change by year')

# %%
q3, q1 = np.percentile(yr_grouped, [75 ,25])
iqr = q3 - q1
print(iqr)
# Out:
# 0.7671704401306165

# %%
ax = sns.histplot(cnam_grouped)
ax.set_title("average temp change by country ")
# Out:
# Text(0.5, 1.0, 'average temp change by country ')

# %%
temp_dat.isnull().sum()
# Out:
# Country Code    2714
# Country Name       0
# year               0
# tem_change      1781
# dtype: int64

# %%
temp_dat.year
# Out:
# 0        1961
# 1        1961
# 2        1961
# 3        1961
# 4        1961
#          ...
# 16751    2019
# 16752    2019
# 16753    2019
# 16754    2019
# 16755    2019
# Name: year, Length: 16756, dtype: int64

# %%
temp_dat['tem_change2'] = temp_dat.loc[:, 'tem_change' ]

# %%
temp_dat.tem_change2.isnull().sum()
# Out:
# 1781

# %%
table1
# Out:
#                    tem_change
# Country Name year
# Afghanistan  1961      -0.080
#              1962      -0.120
#              1963       0.882
#              1964      -0.727
#              1965      -0.200
# ...                       ...
# Zimbabwe     2015       1.091
#              2016       1.303
#              2017       0.269
#              2018       0.496
#              2019       1.157
#
# [16756 rows x 1 columns]

# %%
table1
# Out:
#                    tem_change
# Country Name year
# Afghanistan  1961      -0.080
#              1962      -0.120
#              1963       0.882
#              1964      -0.727
#              1965      -0.200
# ...                       ...
# Zimbabwe     2015       1.091
#              2016       1.303
#              2017       0.269
#              2018       0.496
#              2019       1.157
#
# [16756 rows x 1 columns]

# %%
table1.loc[ : , 'tem_change']
# Out:
# Country Name  year
# Afghanistan   1961   -0.080
#               1962   -0.120
#               1963    0.882
#               1964   -0.727
#               1965   -0.200
#                       ...
# Zimbabwe      2015    1.091
#               2016    1.303
#               2017    0.269
#               2018    0.496
#               2019    1.157
# Name: tem_change, Length: 16756, dtype: float64

# %%
#loop over the countries ! and fill nan from previous entries

# %%
temp_dat.duplicated().sum()
#no duplicated items
# Out:
# 0

# %%
null_percent = temp_dat.tem_change.isnull().sum() /( temp_dat.tem_change.count() + temp_dat.tem_change.isnull().sum() )* 100

# %%
print("the percent of null data is " + null_percent.astype('str') + ' %')
# Out:
# the percent of null data is 10.629028407734543 %
